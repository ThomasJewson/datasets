# %% [markdown]
# # Questions from lesson 1

# %% [markdown]
# **Question 1:**
#
# Plot a histogram of the `sepal_width` from the `IrisDF` DataFrame below with 15 bins.

# %%
import pandas as pd 
IrisDF = pd.read_csv("https://raw.githubusercontent.com/ThomasJewson/datasets/master/Iris.csv")
IrisDF
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Solution
IrisDF.plot.hist(
    y="sepal_width",
    bins=15
)

# %% [markdown]
# **Question 2:**
#
# *Below is some data of the average income per head in thousands of Euros. [1]. Output the following countries on a line plot: `Ireland`, `Greece`, `Luxembourg` and the `United Kingdom`.*
#
# *Give the graph the following attributes:*
#
# - Title of "Average income per head in thousands of Euros"
#
# - Figure size of `(15,10)`

# %%
IncomeDF = pd.read_csv("https://raw.githubusercontent.com/ThomasJewson/datasets/master/IncomePerHead2-1000EURO.csv")
IncomeDF
# Out:
#     Year   Estonia   Ireland    Greece     Spain    France   Croatia  \
# 0   2001   4.79376  26.95836  14.08208  16.95752  25.52541   5.92490
# 1   2002   5.40621  28.98963  15.12429  17.88988  25.96231   6.51413
# 2   2003   6.02493  31.39469  16.31494  18.85671  26.54952   6.89318
# 3   2004   6.81257  33.13256  17.58553  19.86562  27.55578   7.64182
# 4   2005   8.03024  35.42639  17.91279  20.94591  28.43438   8.27561
# 5   2006   9.54626  37.99648  19.40415  22.21024  29.63619   9.08851
# 6   2007  11.42086  38.75035  20.52032  23.19272  30.93485   9.96375
# 7   2008  11.78260  36.16572  21.19388  23.45947  31.63066  10.83895
# 8   2009  10.31768  31.32684  20.91127  22.62032  30.62137  10.10234
# 9   2010  10.55336  30.81918  19.90772  22.70229  31.40200  10.15446
# 10  2011  12.01599  30.31774  18.13296  22.35932  32.34488  10.13175
# 11  2012  13.06075  30.72609  17.42650  21.87151  32.51245  10.00927
# 12  2013  14.07010  32.86549  16.45663  21.75281  32.80163  10.01843
# ...

# %%
#Solution
IncomeDF.plot.line(
    x="Year",
    y=["Ireland","Greece","Luxembourg","United Kingdom"],

    
    title="Average income per head in thousands of Euros",
    figsize=(15,10),
)

# %% [markdown]
# **Question 3**
#
# Plot a bar chart with the `IncomeDF` DataFrame of the average income per head of per 1000 Euros of United States and France on the same plot.
#
# Give the United States red bars and France blue bars.

# %%
#Solution
IncomeDF.plot.bar(
    x="Year",
    y=["United States","France"],
    color=["red","blue"]
)

# %% [markdown]
# **Question 4:**
#
#
# *Below produces a pivot table from the `CheeseDF` we saw in the questions from Lesson 2.*
#
# *Plot a pie chart of the `Units Sold` from the `CheesePiv` DataFrame*

# %%
import numpy as np
CheeseDF = pd.read_csv("https://raw.githubusercontent.com/ThomasJewson/datasets/master/CheeseShop.csv")
CheesePiv=CheeseDF.pivot_table(index=["Cheese"],aggfunc=np.sum,values="Units Sold")
CheesePiv
# Out:
#          Units Sold
# Cheese
# Cheddar      118348
# Edam           5447
# Stilton        1013

# %%
#Solution
CheesePiv.plot.pie(
    y="Units Sold"
)

# %% [markdown]
# **Question 5:**
#
# *From the `IrisDF` plot the `petal_width` and the `petal_length` on the same histogram.*
#
# *Give `petal_width` the colour `navy` and `petal_length` the colour `orange`.*
#
# *Give the plot an appropriate title, grid lines and 15 bins.*

# %%
#Solution
IrisDF.plot.hist(
    y=["petal_width","petal_length"],
    color = ["navy","orange"],
    title="Histogram of Petal widths and lengths",
    grid=True,
    bins=15
)

# %% [markdown]
# **Sources:**
#
# [1] https://ec.europa.eu/info/business-economy-euro/indicators-statistics/economic-databases/macro-economic-database-ameco/download-annual-data-set-macro-economic-database-ameco_en
